# %%
import pandas as pd
import numpy as np

# %%
Heart_desies=pd.read_csv('D:\Graduation Project\heart_2022_with_nans.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2726832299.py:1: SyntaxWarning: invalid escape sequence '\G'
#   Heart_desies=pd.read_csv('D:\Graduation Project\heart_2022_with_nans.csv')

# %%
Heart_desies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      445132 non-null  object
#  1   Sex                        445132 non-null  object
#  2   GeneralHealth              443934 non-null  object
#  3   PhysicalHealthDays         434205 non-null  float64
#  4   MentalHealthDays           436065 non-null  float64
#  5   LastCheckupTime            436824 non-null  object
#  6   PhysicalActivities         444039 non-null  object
#  7   SleepHours                 439679 non-null  float64
#  8   RemovedTeeth               433772 non-null  object
#  9   HadHeartAttack             442067 non-null  object
#  10  HadAngina                  440727 non-null  object
#  11  HadStroke                  443575 non-null  object
#  12  HadAsthma                  443359 non-null  object
# ...

# %%
Heart_desies.isna().sum()
# Out:
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays           10927
# MentalHealthDays              9067
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                    5453
# RemovedTeeth                 11360
# HadHeartAttack                3065
# HadAngina                     4405
# HadStroke                     1557
# HadAsthma                     1773
# HadSkinCancer                 3143
# HadCOPD                       2219
# HadDepressiveDisorder         2812
# HadKidneyDisease              1926
# HadArthritis                  2633
# HadDiabetes                   1087
# DeafOrHardOfHearing          20647
# BlindOrVisionDifficulty      21564
# DifficultyConcentrating      24240
# DifficultyWalking            24012
# DifficultyDressingBathing    23915
# DifficultyErrands            25656
# SmokerStatus                 35462
# ECigaretteUsage              35660
# ...

# %%
Heart_desies.describe().round()
# Out:
#        PhysicalHealthDays  MentalHealthDays  SleepHours  HeightInMeters  \
# count            434205.0          436065.0    439679.0        416480.0
# mean                  4.0               4.0         7.0             2.0
# std                   9.0               8.0         2.0             0.0
# min                   0.0               0.0         1.0             1.0
# 25%                   0.0               0.0         6.0             2.0
# 50%                   0.0               0.0         7.0             2.0
# 75%                   3.0               5.0         8.0             2.0
# max                  30.0              30.0        24.0             2.0
#
#        WeightInKilograms       BMI
# count           403054.0  396326.0
# mean                83.0      29.0
# std                 21.0       7.0
# min                 23.0      12.0
# 25%                 68.0      24.0
# 50%                 81.0      27.0
# 75%                 95.0      32.0
# ...

# %%
x=Heart_desies['PhysicalHealthDays'].mean().round()
Heart_desies['PhysicalHealthDays'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\643002523.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['PhysicalHealthDays'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays               0
# MentalHealthDays              9067
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                    5453
# RemovedTeeth                 11360
# ...

# %%
x=Heart_desies['MentalHealthDays'].mean().round()
Heart_desies['MentalHealthDays'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3874597709.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['MentalHealthDays'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                    5453
# RemovedTeeth                 11360
# ...

# %%
x=Heart_desies['SleepHours'].mean().round()
Heart_desies['SleepHours'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2180897800.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['SleepHours'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                 1198
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                       0
# RemovedTeeth                 11360
# ...

# %%
x=Heart_desies['GeneralHealth'].mode()[0]
Heart_desies['GeneralHealth'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3751827336.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['GeneralHealth'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                       0
# RemovedTeeth                 11360
# ...

# %%
x=Heart_desies['HeightInMeters'].mean().round()
Heart_desies['HeightInMeters'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\322169133.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HeightInMeters'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                       0
# RemovedTeeth                 11360
# ...

# %%
x=Heart_desies['WeightInKilograms'].mean().round()
Heart_desies['WeightInKilograms'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3711722274.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['WeightInKilograms'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                       0
# RemovedTeeth                 11360
# ...

# %%
x=Heart_desies['BMI'].mean().round()
Heart_desies['BMI'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2191949870.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['BMI'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime               8308
# PhysicalActivities            1093
# SleepHours                       0
# RemovedTeeth                 11360
# ...

# %%
Heart_desies.describe().round()
# Out:
#        PhysicalHealthDays  MentalHealthDays  SleepHours  HeightInMeters  \
# count            445132.0          445132.0    445132.0        445132.0
# mean                  4.0               4.0         7.0             2.0
# std                   9.0               8.0         1.0             0.0
# min                   0.0               0.0         1.0             1.0
# 25%                   0.0               0.0         6.0             2.0
# 50%                   0.0               0.0         7.0             2.0
# 75%                   4.0               4.0         8.0             2.0
# max                  30.0              30.0        24.0             2.0
#
#        WeightInKilograms       BMI
# count           445132.0  445132.0
# mean                83.0      29.0
# std                 20.0       6.0
# min                 23.0      12.0
# 25%                 68.0      24.0
# 50%                 82.0      28.0
# 75%                 92.0      31.0
# ...

# %%
x=Heart_desies['LastCheckupTime'].mode()[0]
Heart_desies['LastCheckupTime'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\4050519456.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['LastCheckupTime'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities            1093
# SleepHours                       0
# RemovedTeeth                 11360
# ...

# %%
x=Heart_desies['PhysicalActivities'].mode()[0]
Heart_desies['PhysicalActivities'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2602388710.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['PhysicalActivities'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                 11360
# ...

# %%
x=Heart_desies['RemovedTeeth'].mode()[0]
Heart_desies['RemovedTeeth'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3218596114.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['RemovedTeeth'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadHeartAttack'].mode()[0]
Heart_desies['HadHeartAttack'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\1821102893.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadHeartAttack'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadAngina'].mode()[0]
Heart_desies['HadAngina'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\770516066.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadAngina'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadStroke'].mode()[0]
Heart_desies['HadStroke'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3634981857.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadStroke'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadAsthma'].mode()[0]
Heart_desies['HadAsthma'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2052187187.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadAsthma'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadSkinCancer'].mode()[0]
Heart_desies['HadSkinCancer'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\1316442468.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadSkinCancer'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadCOPD'].mode()[0]
Heart_desies['HadCOPD'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2720642383.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadCOPD'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadDepressiveDisorder'].mode()[0]
Heart_desies['HadDepressiveDisorder'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3192152044.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadDepressiveDisorder'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadKidneyDisease'].mode()[0]
Heart_desies['HadKidneyDisease'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\97854595.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadKidneyDisease'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadArthritis'].mode()[0]
Heart_desies['HadArthritis'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\4151409611.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadArthritis'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HadDiabetes'].mode()[0]
Heart_desies['HadDiabetes'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3268508064.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HadDiabetes'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['DeafOrHardOfHearing'].mode()[0]
Heart_desies['DeafOrHardOfHearing'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\4114860245.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['DeafOrHardOfHearing'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['BlindOrVisionDifficulty'].mode()[0]
Heart_desies['BlindOrVisionDifficulty'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2310613787.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['BlindOrVisionDifficulty'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['DifficultyConcentrating'].mode()[0]
Heart_desies['DifficultyConcentrating'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\743688263.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['DifficultyConcentrating'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['DifficultyWalking'].mode()[0]
Heart_desies['DifficultyWalking'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3659250995.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['DifficultyWalking'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['DifficultyDressingBathing'].mode()[0]
Heart_desies['DifficultyDressingBathing'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3143161148.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['DifficultyDressingBathing'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['DifficultyErrands'].mode()[0]
Heart_desies['DifficultyErrands'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\4024308522.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['DifficultyErrands'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['SmokerStatus'].mode()[0]
Heart_desies['SmokerStatus'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\4094841394.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['SmokerStatus'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['ECigaretteUsage'].mode()[0]
Heart_desies['ECigaretteUsage'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3898748706.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['ECigaretteUsage'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['ChestScan'].mode()[0]
Heart_desies['ChestScan'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3985957343.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['ChestScan'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['RaceEthnicityCategory'].mode()[0]
Heart_desies['RaceEthnicityCategory'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2657131654.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['RaceEthnicityCategory'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['AgeCategory'].mode()[0]
Heart_desies['AgeCategory'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\1435340344.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['AgeCategory'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['AlcoholDrinkers'].mode()[0]
Heart_desies['AlcoholDrinkers'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\1534722094.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['AlcoholDrinkers'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HIVTesting'].mode()[0]
Heart_desies['HIVTesting'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3725506593.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HIVTesting'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['FluVaxLast12'].mode()[0]
Heart_desies['FluVaxLast12'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3653230499.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['FluVaxLast12'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['PneumoVaxEver'].mode()[0]
Heart_desies['PneumoVaxEver'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\628281198.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['PneumoVaxEver'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['TetanusLast10Tdap'].mode()[0]
Heart_desies['TetanusLast10Tdap'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\2414123816.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['TetanusLast10Tdap'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['HighRiskLastYear'].mode()[0]
Heart_desies['HighRiskLastYear'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\1680316283.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['HighRiskLastYear'].fillna(x,inplace=True)
# State                            0
# Sex                              0
# GeneralHealth                    0
# PhysicalHealthDays               0
# MentalHealthDays                 0
# LastCheckupTime                  0
# PhysicalActivities               0
# SleepHours                       0
# RemovedTeeth                     0
# ...

# %%
x=Heart_desies['CovidPos'].mode()[0]
Heart_desies['CovidPos'].fillna(x,inplace=True)
Heart_desies.isna().sum()
# Out:
# C:\Users\lesho\AppData\Local\Temp\ipykernel_13636\3185307418.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Heart_desies['CovidPos'].fillna(x,inplace=True)
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# RemovedTeeth                 0
# HadHeartAttack               0
# ...

# %%
Heart_desies.isna().sum()
# Out:
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# RemovedTeeth                 0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadSkinCancer                0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# DeafOrHardOfHearing          0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# DifficultyErrands            0
# SmokerStatus                 0
# ECigaretteUsage              0
# ChestScan                    0
# RaceEthnicityCategory        0
# AgeCategory                  0
# ...

# %%
Heart_desies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 445132 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      445132 non-null  object
#  1   Sex                        445132 non-null  object
#  2   GeneralHealth              445132 non-null  object
#  3   PhysicalHealthDays         445132 non-null  float64
#  4   MentalHealthDays           445132 non-null  float64
#  5   LastCheckupTime            445132 non-null  object
#  6   PhysicalActivities         445132 non-null  object
#  7   SleepHours                 445132 non-null  float64
#  8   RemovedTeeth               445132 non-null  object
#  9   HadHeartAttack             445132 non-null  object
#  10  HadAngina                  445132 non-null  object
#  11  HadStroke                  445132 non-null  object
#  12  HadAsthma                  445132 non-null  object
# ...

# %%
Heart_desies.head(15)
# Out:
#       State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 0   Alabama  Female     Very good                 0.0               0.0
# 1   Alabama  Female     Excellent                 0.0               0.0
# 2   Alabama  Female     Very good                 2.0               3.0
# 3   Alabama  Female     Excellent                 0.0               0.0
# 4   Alabama  Female          Fair                 2.0               0.0
# 5   Alabama    Male          Poor                 1.0               0.0
# 6   Alabama  Female     Very good                 0.0               0.0
# 7   Alabama  Female          Good                 0.0               0.0
# 8   Alabama  Female          Good                 0.0               0.0
# 9   Alabama  Female          Good                 1.0               0.0
# 10  Alabama  Female          Fair                 8.0               9.0
# 11  Alabama  Female          Good                 0.0               0.0
# ...

# %%
Heart_desies.to_excel('heart_2022_with_nans_cleaned.xlsx',index=False)

# %%
import os
print(os.getcwd())
# Out:
# d:\Graduation Project

# %%
for i in Heart_desies:
    if Heart_desies.duplicated:
        print(Heart_desies.duplicated())
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 445127    False
# 445128    False
# 445129    False
# 445130    False
# 445131    False
# Length: 445132, dtype: bool
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 445127    False
# 445128    False
# 445129    False
# 445130    False
# 445131    False
# Length: 445132, dtype: bool
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 445127    False
# 445128    False
# 445129    False
# 445130    False
# 445131    False
# Length: 445132, dtype: bool
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 445127    False
# 445128    False
# 445129    False
# 445130    False
# 445131    False
# Length: 445132, dtype: bool
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ...

# %%
duplicates = Heart_desies[Heart_desies.duplicated()]
print(duplicates)
# Out:
#             State     Sex GeneralHealth  PhysicalHealthDays  MentalHealthDays  \
# 7310       Alaska    Male     Very good                 0.0               0.0
# 9475       Alaska  Female     Excellent                 0.0               0.0
# 11503     Arizona  Female     Excellent                 0.0               0.0
# 14642     Arizona  Female     Excellent                 0.0               0.0
# 17733     Arizona    Male          Good                 0.0               0.0
# ...           ...     ...           ...                 ...               ...
# 424819  Wisconsin  Female     Very good                 0.0               0.0
# 427638  Wisconsin    Male     Very good                 0.0               0.0
# 431351  Wisconsin    Male          Good                 0.0               0.0
# 431653  Wisconsin    Male     Excellent                 0.0               0.0
# 433508    Wyoming  Female          Good                 0.0               0.0
#
# ...

# %%
Heart_desies.drop_duplicates(inplace=True)

# %%
Heart_desies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 444810 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      444810 non-null  object
#  1   Sex                        444810 non-null  object
#  2   GeneralHealth              444810 non-null  object
#  3   PhysicalHealthDays         444810 non-null  float64
#  4   MentalHealthDays           444810 non-null  float64
#  5   LastCheckupTime            444810 non-null  object
#  6   PhysicalActivities         444810 non-null  object
#  7   SleepHours                 444810 non-null  float64
#  8   RemovedTeeth               444810 non-null  object
#  9   HadHeartAttack             444810 non-null  object
#  10  HadAngina                  444810 non-null  object
#  11  HadStroke                  444810 non-null  object
#  12  HadAsthma                  444810 non-null  object
# ...

# %%
Heart_desies.to_excel('heart_2022_with_nans_cleaned.xlsx',index=False)

# %%
Heart_desies.isna().sum()
# Out:
# State                        0
# Sex                          0
# GeneralHealth                0
# PhysicalHealthDays           0
# MentalHealthDays             0
# LastCheckupTime              0
# PhysicalActivities           0
# SleepHours                   0
# RemovedTeeth                 0
# HadHeartAttack               0
# HadAngina                    0
# HadStroke                    0
# HadAsthma                    0
# HadSkinCancer                0
# HadCOPD                      0
# HadDepressiveDisorder        0
# HadKidneyDisease             0
# HadArthritis                 0
# HadDiabetes                  0
# DeafOrHardOfHearing          0
# BlindOrVisionDifficulty      0
# DifficultyConcentrating      0
# DifficultyWalking            0
# DifficultyDressingBathing    0
# DifficultyErrands            0
# SmokerStatus                 0
# ECigaretteUsage              0
# ChestScan                    0
# RaceEthnicityCategory        0
# AgeCategory                  0
# ...

# %%
Heart_desies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 444810 entries, 0 to 445131
# Data columns (total 40 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State                      444810 non-null  object
#  1   Sex                        444810 non-null  object
#  2   GeneralHealth              444810 non-null  object
#  3   PhysicalHealthDays         444810 non-null  float64
#  4   MentalHealthDays           444810 non-null  float64
#  5   LastCheckupTime            444810 non-null  object
#  6   PhysicalActivities         444810 non-null  object
#  7   SleepHours                 444810 non-null  float64
#  8   RemovedTeeth               444810 non-null  object
#  9   HadHeartAttack             444810 non-null  object
#  10  HadAngina                  444810 non-null  object
#  11  HadStroke                  444810 non-null  object
#  12  HadAsthma                  444810 non-null  object
# ...
